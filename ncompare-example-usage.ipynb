# %% [markdown]
# # Brief demonstration of `ncompare` - a netCDF comparison tool
#
# Installation instructions can be found in either of these locations:
#   - [GitHub repository](https://github.com/nasa/ncompare)
#   - [Pip entry](https://pypi.org/project/ncompare/)
#
# Notebook created: 23 October 2023

# %% [markdown]
# ## `ncompare`'s command line arguments, provided by the `--help` description

# %% [markdown]
# ***✍️ Syntax Note:*** Commands preceeded by an exclamation point "!"
# (which is needed to [run shell commands in a Jupyter notebook](https://stackoverflow.com/a/48529220)) can be run from a terminal.
# In a shell/terminal, the exclamation point should not be used.

# %%
! ncompare --help
# Out:
# usage: ncompare [-h] [-v COMPARISON_VAR_NAME] [-g COMPARISON_VAR_GROUP]
#                 [--file-text FILE_TEXT] [--file-csv FILE_CSV]
#                 [--file-xlsx FILE_XLSX] [--no-color] [--show-attributes]
#                 [--show-chunks]
#                 nc_a nc_b
#
# Compare the variables contained within two different NetCDF datasets
#
# positional arguments:
#   nc_a                  First NetCDF file
#   nc_b                  First NetCDF file
#
# options:
#   -h, --help            show this help message and exit
#   -v COMPARISON_VAR_NAME, --comparison_var_name COMPARISON_VAR_NAME
#                         Comparison variable name
#   -g COMPARISON_VAR_GROUP, --comparison_var_group COMPARISON_VAR_GROUP
#                         Comparison variable group
#   --file-text FILE_TEXT
#                         A text file to which the output will be written.
#   --file-csv FILE_CSV   A csv (comma separated values) file to which the
#                         output will be written.
#   --file-xlsx FILE_XLSX
#                         An Excel file to which the output will be written.
#   --no-color            Turn off all colorized output
#   --show-attributes     Include variable attributes in comparison
#   --show-chunks         Include chunk sizes in the table that compares
#                         variables

# %% [markdown]
# ## An example of `ncompare`'s output, when the two specified files have the same groups, variables, and attributes

# %% [markdown]
# The two files are first defined. These two files are from NASA's Measurements Of Pollution In The Troposphere (MOPITT) instrument.

# %%
filepath_1 = "notebook_example_data/MOP03JM-202205-L3V95.6.3.he5"
filepath_2 = "notebook_example_data/MOP03JM-202205-L3V95.9.3.he5"

# %% [markdown]
# Next, we pass the two filepaths to `ncompare`, and any differences would be printed in red. In this case, there are no differences; therefore, all of the variables are printed in black.

# %% [markdown]
# ***✍️ Syntax Note:*** the curly brackets, "{" and "}", that follow are simply a way to [substitute python variables into a shell command](https://stackoverflow.com/a/35497161).
# In a shell/terminal, one can just write out the full arguments, separated by spaces.
# For example, the following command would be run at the terminal as `ncompare notebook_example_data/MOP03JM-202205-L3V95.6.3.he5 notebook_example_data/MOP03JM-202205-L3V95.9.3.he5`

# %%
! ncompare {filepath_1} {filepath_2}
# Out:
# File A: notebook_example_data/MOP03JM-202205-L3V95.6.3.he5
# File B: notebook_example_data/MOP03JM-202205-L3V95.9.3.he5
#                                    notebook_example_data/MOP03JM-202205-L3V95.6.3.he5 notebook_example_data/MOP03JM-202205-L3V95.9.3.he5
#
# Root-level Dimensions:
# 	Are all items the same? ---> True.  (No items exist.)
#
# Root-level Groups:
# 	Are all items the same? ---> True.
# 	['HDFEOS', 'HDFEOS INFORMATION']
#
# No variable group selected for comparison. Skipping..
#
# All variables:
#                                                                              File A                                           File B
#                      All Variables
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #00 -----------------------------------------------/ -----------------------------------------------/
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #01 -----------------------------------------/HDFEOS -----------------------------------------/HDFEOS
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #02 -----------------------------/HDFEOS INFORMATION -----------------------------/HDFEOS INFORMATION
#            num variables in group:                                                2                                                2
#                                  - ------------------------------------------------ ------------------------------------------------
#                -----VARIABLE-----:                                 StructMetadata.0                                 StructMetadata.0
#                             dtype:                                    <class 'str'>                                    <class 'str'>
#                             shape:                                               ()                                               ()
#                -----VARIABLE-----:                                   coremetadata.0                                   coremetadata.0
#                             dtype:                                    <class 'str'>                                    <class 'str'>
#                             shape:                                             (1,)                                             (1,)
#
#                          GROUP #03 ------------------------------/HDFEOS/ADDITIONAL ------------------------------/HDFEOS/ADDITIONAL
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #04 -----------------------------------/HDFEOS/GRIDS -----------------------------------/HDFEOS/GRIDS
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #05 --------------/HDFEOS/ADDITIONAL/FILE_ATTRIBUTES --------------/HDFEOS/ADDITIONAL/FILE_ATTRIBUTES
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #06 -----------------------------/HDFEOS/GRIDS/MOP03 -----------------------------/HDFEOS/GRIDS/MOP03
#            num variables in group:                                                6                                                6
#                                  - ------------------------------------------------ ------------------------------------------------
#                -----VARIABLE-----:                                             NTWO                                             NTWO
#                             dtype:                                            int32                                            int32
#                             shape:                                             (2,)                                             (2,)
#                -----VARIABLE-----:                                              Prs                                              Prs
#                             dtype:                                          float32                                          float32
#                             shape:                                             (9,)                                             (9,)
#                -----VARIABLE-----:                                             Prs1                                             Prs1
#                             dtype:                                          float32                                          float32
#                             shape:                                            (10,)                                            (10,)
#                -----VARIABLE-----:                                             Prs2                                             Prs2
#                             dtype:                                          float32                                          float32
#                             shape:                                            (10,)                                            (10,)
#                -----VARIABLE-----:                                             XDim                                             XDim
#                             dtype:                                          float64                                          float64
#                             shape:                                           (360,)                                           (360,)
#                -----VARIABLE-----:                                             YDim                                             YDim
#                             dtype:                                          float64                                          float64
#                             shape:                                           (180,)                                           (180,)
#
#                          GROUP #07 -----------------/HDFEOS/GRIDS/MOP03/Data Fields -----------------/HDFEOS/GRIDS/MOP03/Data Fields
#            num variables in group:                                               80                                               80
#                                  - ------------------------------------------------ ------------------------------------------------
#                -----VARIABLE-----:                   APrioriCOMixingRatioProfileDay                   APrioriCOMixingRatioProfileDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:                 APrioriCOMixingRatioProfileNight                 APrioriCOMixingRatioProfileNight
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:                   APrioriCOSurfaceMixingRatioDay                   APrioriCOSurfaceMixingRatioDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                 APrioriCOSurfaceMixingRatioNight                 APrioriCOSurfaceMixingRatioNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                          APrioriCOTotalColumnDay                          APrioriCOTotalColumnDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                        APrioriCOTotalColumnNight                        APrioriCOTotalColumnNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                      APrioriSurfaceEmissivityDay                      APrioriSurfaceEmissivityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                    APrioriSurfaceEmissivityNight                    APrioriSurfaceEmissivityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                     APrioriSurfaceTemperatureDay                     APrioriSurfaceTemperatureDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                   APrioriSurfaceTemperatureNight                   APrioriSurfaceTemperatureNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                   DEMAltitudeDay                                   DEMAltitudeDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                 DEMAltitudeNight                                 DEMAltitudeNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                        DEMAltitudeVariabilityDay                        DEMAltitudeVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                      DEMAltitudeVariabilityNight                      DEMAltitudeVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                     DegreesofFreedomforSignalDay                     DegreesofFreedomforSignalDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                   DegreesofFreedomforSignalNight                   DegreesofFreedomforSignalNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                  DryAirColumnDay                                  DryAirColumnDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                DryAirColumnNight                                DryAirColumnNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                         Latitude                                         Latitude
#                             dtype:                                          float32                                          float32
#                             shape:                                           (180,)                                           (180,)
#                -----VARIABLE-----:                                        Longitude                                        Longitude
#                             dtype:                                          float32                                          float32
#                             shape:                                           (360,)                                           (360,)
#                -----VARIABLE-----:              MeasurementErrorCovarianceMatrixDay              MeasurementErrorCovarianceMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:            MeasurementErrorCovarianceMatrixNight            MeasurementErrorCovarianceMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:                                NumberofPixelsDay                                NumberofPixelsDay
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                              NumberofPixelsNight                              NumberofPixelsNight
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                         Pressure                                         Pressure
#                             dtype:                                          float32                                          float32
#                             shape:                                             (9,)                                             (9,)
#                -----VARIABLE-----:                                        Pressure2                                        Pressure2
#                             dtype:                                          float32                                          float32
#                             shape:                                            (10,)                                            (10,)
#                -----VARIABLE-----:                RetrievalAveragingKernelMatrixDay                RetrievalAveragingKernelMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:              RetrievalAveragingKernelMatrixNight              RetrievalAveragingKernelMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:                RetrievalErrorCovarianceMatrixDay                RetrievalErrorCovarianceMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:              RetrievalErrorCovarianceMatrixNight              RetrievalErrorCovarianceMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:                 RetrievedCOMixingRatioProfileDay                 RetrievedCOMixingRatioProfileDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:  RetrievedCOMixingRatioProfileMeanUncertaintyDay  RetrievedCOMixingRatioProfileMeanUncertaintyDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:  RetrievedCOMixingRatioProfileMeanUncertaintyNig  RetrievedCOMixingRatioProfileMeanUncertaintyNig
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:               RetrievedCOMixingRatioProfileNight               RetrievedCOMixingRatioProfileNight
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:      RetrievedCOMixingRatioProfileVariabilityDay      RetrievedCOMixingRatioProfileVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:    RetrievedCOMixingRatioProfileVariabilityNight    RetrievedCOMixingRatioProfileVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                -----VARIABLE-----:                 RetrievedCOSurfaceMixingRatioDay                 RetrievedCOSurfaceMixingRatioDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:  RetrievedCOSurfaceMixingRatioMeanUncertaintyDay  RetrievedCOSurfaceMixingRatioMeanUncertaintyDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:  RetrievedCOSurfaceMixingRatioMeanUncertaintyNig  RetrievedCOSurfaceMixingRatioMeanUncertaintyNig
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:               RetrievedCOSurfaceMixingRatioNight               RetrievedCOSurfaceMixingRatioNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:      RetrievedCOSurfaceMixingRatioVariabilityDay      RetrievedCOSurfaceMixingRatioVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:    RetrievedCOSurfaceMixingRatioVariabilityNight    RetrievedCOSurfaceMixingRatioVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                        RetrievedCOTotalColumnDay                        RetrievedCOTotalColumnDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:             RetrievedCOTotalColumnDiagnosticsDay             RetrievedCOTotalColumnDiagnosticsDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 2)                                    (360, 180, 2)
#                -----VARIABLE-----:           RetrievedCOTotalColumnDiagnosticsNight           RetrievedCOTotalColumnDiagnosticsNight
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 2)                                    (360, 180, 2)
#                -----VARIABLE-----:         RetrievedCOTotalColumnMeanUncertaintyDay         RetrievedCOTotalColumnMeanUncertaintyDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:       RetrievedCOTotalColumnMeanUncertaintyNight       RetrievedCOTotalColumnMeanUncertaintyNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                      RetrievedCOTotalColumnNight                      RetrievedCOTotalColumnNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:             RetrievedCOTotalColumnVariabilityDay             RetrievedCOTotalColumnVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:           RetrievedCOTotalColumnVariabilityNight           RetrievedCOTotalColumnVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                    RetrievedSurfaceEmissivityDay                    RetrievedSurfaceEmissivityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:     RetrievedSurfaceEmissivityMeanUncertaintyDay     RetrievedSurfaceEmissivityMeanUncertaintyDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:   RetrievedSurfaceEmissivityMeanUncertaintyNight   RetrievedSurfaceEmissivityMeanUncertaintyNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                  RetrievedSurfaceEmissivityNight                  RetrievedSurfaceEmissivityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:         RetrievedSurfaceEmissivityVariabilityDay         RetrievedSurfaceEmissivityVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:       RetrievedSurfaceEmissivityVariabilityNight       RetrievedSurfaceEmissivityVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                   RetrievedSurfaceTemperatureDay                   RetrievedSurfaceTemperatureDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:    RetrievedSurfaceTemperatureMeanUncertaintyDay    RetrievedSurfaceTemperatureMeanUncertaintyDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:  RetrievedSurfaceTemperatureMeanUncertaintyNight  RetrievedSurfaceTemperatureMeanUncertaintyNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                 RetrievedSurfaceTemperatureNight                 RetrievedSurfaceTemperatureNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:        RetrievedSurfaceTemperatureVariabilityDay        RetrievedSurfaceTemperatureVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:      RetrievedSurfaceTemperatureVariabilityNight      RetrievedSurfaceTemperatureVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                          SatelliteZenithAngleDay                          SatelliteZenithAngleDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                        SatelliteZenithAngleNight                        SatelliteZenithAngleNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                    SignalChi2Day                                    SignalChi2Day
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                  SignalChi2Night                                  SignalChi2Night
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                         SignalChi2VariabilityDay                         SignalChi2VariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                       SignalChi2VariabilityNight                       SignalChi2VariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                SmoothingErrorCovarianceMatrixDay                SmoothingErrorCovarianceMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:              SmoothingErrorCovarianceMatrixNight              SmoothingErrorCovarianceMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                -----VARIABLE-----:                              SolarZenithAngleDay                              SolarZenithAngleDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                            SolarZenithAngleNight                            SolarZenithAngleNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                  SurfaceIndexDay                                  SurfaceIndexDay
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                                SurfaceIndexNight                                SurfaceIndexNight
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                               SurfacePressureDay                               SurfacePressureDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                             SurfacePressureNight                             SurfacePressureNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                    TotalColumnAveragingKernelDay                    TotalColumnAveragingKernelDay
#                             dtype:                                          float32                                          float32
#                             shape:                                   (360, 180, 10)                                   (360, 180, 10)
#                -----VARIABLE-----:                  TotalColumnAveragingKernelNight                  TotalColumnAveragingKernelNight
#                             dtype:                                          float32                                          float32
#                             shape:                                   (360, 180, 10)                                   (360, 180, 10)
#                -----VARIABLE-----:                              WaterVaporColumnDay                              WaterVaporColumnDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                -----VARIABLE-----:                            WaterVaporColumnNight                            WaterVaporColumnNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                                  - ------------------------------------------------ ------------------------------------------------
#      Total number of shared items:                                               88                                               88
#  Total number of non-shared items:                                                0                                                0
#
# Done.

# %% [markdown]
# #### More file details can be examined by using the `--show-attributes` and `--show-chunks` options

# %%
! ncompare --show-attributes --show-chunks {filepath_1} {filepath_2}
# Out:
# File A: notebook_example_data/MOP03JM-202205-L3V95.6.3.he5
# File B: notebook_example_data/MOP03JM-202205-L3V95.9.3.he5
#                                    notebook_example_data/MOP03JM-202205-L3V95.6.3.he5 notebook_example_data/MOP03JM-202205-L3V95.9.3.he5
#
# Root-level Dimensions:
# 	Are all items the same? ---> True.  (No items exist.)
#
# Root-level Groups:
# 	Are all items the same? ---> True.
# 	['HDFEOS', 'HDFEOS INFORMATION']
#
# No variable group selected for comparison. Skipping..
#
# All variables:
#                                                                              File A                                           File B
#                      All Variables
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #00 -----------------------------------------------/ -----------------------------------------------/
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #01 -----------------------------------------/HDFEOS -----------------------------------------/HDFEOS
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #02 -----------------------------/HDFEOS INFORMATION -----------------------------/HDFEOS INFORMATION
#            num variables in group:                                                2                                                2
#                                  - ------------------------------------------------ ------------------------------------------------
#                -----VARIABLE-----:                                 StructMetadata.0                                 StructMetadata.0
#                             dtype:                                    <class 'str'>                                    <class 'str'>
#                             shape:                                               ()                                               ()
#                         chunksize:                                       contiguous                                       contiguous
#                -----VARIABLE-----:                                   coremetadata.0                                   coremetadata.0
#                             dtype:                                    <class 'str'>                                    <class 'str'>
#                             shape:                                             (1,)                                             (1,)
#                         chunksize:                                       contiguous                                       contiguous
#
#                          GROUP #03 ------------------------------/HDFEOS/ADDITIONAL ------------------------------/HDFEOS/ADDITIONAL
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #04 -----------------------------------/HDFEOS/GRIDS -----------------------------------/HDFEOS/GRIDS
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #05 --------------/HDFEOS/ADDITIONAL/FILE_ATTRIBUTES --------------/HDFEOS/ADDITIONAL/FILE_ATTRIBUTES
#            num variables in group:                                                0                                                0
#                                  - ------------------------------------------------ ------------------------------------------------
#
#                          GROUP #06 -----------------------------/HDFEOS/GRIDS/MOP03 -----------------------------/HDFEOS/GRIDS/MOP03
#            num variables in group:                                                6                                                6
#                                  - ------------------------------------------------ ------------------------------------------------
#                -----VARIABLE-----:                                             NTWO                                             NTWO
#                             dtype:                                            int32                                            int32
#                             shape:                                             (2,)                                             (2,)
#                         chunksize:                                       contiguous                                       contiguous
#                -----VARIABLE-----:                                              Prs                                              Prs
#                             dtype:                                          float32                                          float32
#                             shape:                                             (9,)                                             (9,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                              hPa                                              hPa
#                -----VARIABLE-----:                                             Prs1                                             Prs1
#                             dtype:                                          float32                                          float32
#                             shape:                                            (10,)                                            (10,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                              hPa                                              hPa
#                -----VARIABLE-----:                                             Prs2                                             Prs2
#                             dtype:                                          float32                                          float32
#                             shape:                                            (10,)                                            (10,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                              hPa                                              hPa
#                -----VARIABLE-----:                                             XDim                                             XDim
#                             dtype:                                          float64                                          float64
#                             shape:                                           (360,)                                           (360,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                     degrees_east                                     degrees_east
#                -----VARIABLE-----:                                             YDim                                             YDim
#                             dtype:                                          float64                                          float64
#                             shape:                                           (180,)                                           (180,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                    degrees_north                                    degrees_north
#
#                          GROUP #07 -----------------/HDFEOS/GRIDS/MOP03/Data Fields -----------------/HDFEOS/GRIDS/MOP03/Data Fields
#            num variables in group:                                               80                                               80
#                                  - ------------------------------------------------ ------------------------------------------------
#                -----VARIABLE-----:                   APrioriCOMixingRatioProfileDay                   APrioriCOMixingRatioProfileDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:             A Priori CO Mixing Ratio Profile Day             A Priori CO Mixing Ratio Profile Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:                 APrioriCOMixingRatioProfileNight                 APrioriCOMixingRatioProfileNight
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:           A Priori CO Mixing Ratio Profile Night           A Priori CO Mixing Ratio Profile Night
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:                   APrioriCOSurfaceMixingRatioDay                   APrioriCOSurfaceMixingRatioDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:             A Priori CO Surface Mixing Ratio Day             A Priori CO Surface Mixing Ratio Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:                 APrioriCOSurfaceMixingRatioNight                 APrioriCOSurfaceMixingRatioNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:           A Priori CO Surface Mixing Ratio Night           A Priori CO Surface Mixing Ratio Night
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:                          APrioriCOTotalColumnDay                          APrioriCOTotalColumnDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                     A Priori CO Total Column Day                     A Priori CO Total Column Day
#                             units:                                         mol/cm^2                                         mol/cm^2
#                -----VARIABLE-----:                        APrioriCOTotalColumnNight                        APrioriCOTotalColumnNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                   A Priori CO Total Column Night                   A Priori CO Total Column Night
#                             units:                                         mol/cm^2                                         mol/cm^2
#                -----VARIABLE-----:                      APrioriSurfaceEmissivityDay                      APrioriSurfaceEmissivityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                  A Priori Surface Emissivity Day                  A Priori Surface Emissivity Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                    APrioriSurfaceEmissivityNight                    APrioriSurfaceEmissivityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                A Priori Surface Emissivity Night                A Priori Surface Emissivity Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                     APrioriSurfaceTemperatureDay                     APrioriSurfaceTemperatureDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                 A Priori Surface Temperature Day                 A Priori Surface Temperature Day
#                             units:                                                K                                                K
#                -----VARIABLE-----:                   APrioriSurfaceTemperatureNight                   APrioriSurfaceTemperatureNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:               A Priori Surface Temperature Night               A Priori Surface Temperature Night
#                             units:                                                K                                                K
#                -----VARIABLE-----:                                   DEMAltitudeDay                                   DEMAltitudeDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                                 DEM Altitude Day                                 DEM Altitude Day
#                             units:                                                m                                                m
#                -----VARIABLE-----:                                 DEMAltitudeNight                                 DEMAltitudeNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                               DEM Altitude Night                               DEM Altitude Night
#                             units:                                                m                                                m
#                -----VARIABLE-----:                        DEMAltitudeVariabilityDay                        DEMAltitudeVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                     DEM Altitude Variability Day                     DEM Altitude Variability Day
#                             units:                                                m                                                m
#                -----VARIABLE-----:                      DEMAltitudeVariabilityNight                      DEMAltitudeVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                   DEM Altitude Variability Night                   DEM Altitude Variability Night
#                             units:                                                m                                                m
#                -----VARIABLE-----:                     DegreesofFreedomforSignalDay                     DegreesofFreedomforSignalDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                Degrees of Freedom for Signal Day                Degrees of Freedom for Signal Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                   DegreesofFreedomforSignalNight                   DegreesofFreedomforSignalNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:              Degrees of Freedom for Signal Night              Degrees of Freedom for Signal Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                                  DryAirColumnDay                                  DryAirColumnDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                               Dry Air Column Day                               Dry Air Column Day
#                             units:                                         mol/cm^2                                         mol/cm^2
#                -----VARIABLE-----:                                DryAirColumnNight                                DryAirColumnNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                             Dry Air Column Night                             Dry Air Column Night
#                             units:                                         mol/cm^2                                         mol/cm^2
#                -----VARIABLE-----:                                         Latitude                                         Latitude
#                             dtype:                                          float32                                          float32
#                             shape:                                           (180,)                                           (180,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                    degrees_north                                    degrees_north
#                -----VARIABLE-----:                                        Longitude                                        Longitude
#                             dtype:                                          float32                                          float32
#                             shape:                                           (360,)                                           (360,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                     degrees_east                                     degrees_east
#                -----VARIABLE-----:              MeasurementErrorCovarianceMatrixDay              MeasurementErrorCovarianceMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:          Measurement Error Covariance Matrix Day          Measurement Error Covariance Matrix Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:            MeasurementErrorCovarianceMatrixNight            MeasurementErrorCovarianceMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:        Measurement Error Covariance Matrix Night        Measurement Error Covariance Matrix Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                                NumberofPixelsDay                                NumberofPixelsDay
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                            -9999                                            -9999
#                         long_name:                              Number of Pixel Day                              Number of Pixel Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                              NumberofPixelsNight                              NumberofPixelsNight
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                            -9999                                            -9999
#                         long_name:                            Number of Pixel Night                            Number of Pixel Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                                         Pressure                                         Pressure
#                             dtype:                                          float32                                          float32
#                             shape:                                             (9,)                                             (9,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                              hPa                                              hPa
#                -----VARIABLE-----:                                        Pressure2                                        Pressure2
#                             dtype:                                          float32                                          float32
#                             shape:                                            (10,)                                            (10,)
#                         chunksize:                                       contiguous                                       contiguous
#                             units:                                              hPa                                              hPa
#                -----VARIABLE-----:                RetrievalAveragingKernelMatrixDay                RetrievalAveragingKernelMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:            Retrieval Averaging Kernel Matrix Day            Retrieval Averaging Kernel Matrix Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:              RetrievalAveragingKernelMatrixNight              RetrievalAveragingKernelMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:          Retrieval Averaging Kernel Matrix Night          Retrieval Averaging Kernel Matrix Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                RetrievalErrorCovarianceMatrixDay                RetrievalErrorCovarianceMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:            Retrieval Error Covariance Matrix Day            Retrieval Error Covariance Matrix Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:              RetrievalErrorCovarianceMatrixNight              RetrievalErrorCovarianceMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:          Retrieval Error Covariance Matrix Night          Retrieval Error Covariance Matrix Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                 RetrievedCOMixingRatioProfileDay                 RetrievedCOMixingRatioProfileDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:            Retrieved CO Mixing Ratio Profile Day            Retrieved CO Mixing Ratio Profile Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:  RetrievedCOMixingRatioProfileMeanUncertaintyDay  RetrievedCOMixingRatioProfileMeanUncertaintyDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name: Retrieved CO Mixing Ratio Profile Mean Uncertainty Day Retrieved CO Mixing Ratio Profile Mean Uncertainty Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:  RetrievedCOMixingRatioProfileMeanUncertaintyNig  RetrievedCOMixingRatioProfileMeanUncertaintyNig
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name: Retrieved CO Mixing Ratio Profile Mean Uncertainty Night Retrieved CO Mixing Ratio Profile Mean Uncertainty Night
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:               RetrievedCOMixingRatioProfileNight               RetrievedCOMixingRatioProfileNight
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:          Retrieved CO Mixing Ratio Profile Night          Retrieved CO Mixing Ratio Profile Night
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:      RetrievedCOMixingRatioProfileVariabilityDay      RetrievedCOMixingRatioProfileVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name: Retrieved CO Mixing Ratio Profile Variability Day Retrieved CO Mixing Ratio Profile Variability Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:    RetrievedCOMixingRatioProfileVariabilityNight    RetrievedCOMixingRatioProfileVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                    (360, 180, 9)                                    (360, 180, 9)
#                         chunksize:                                      [60, 30, 9]                                      [60, 30, 9]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name: Retrieved CO Mixing Ratio Profile Variability Night Retrieved CO Mixing Ratio Profile Variability Night
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:                 RetrievedCOSurfaceMixingRatioDay                 RetrievedCOSurfaceMixingRatioDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:            Retrieved CO Surface Mixing Ratio Day            Retrieved CO Surface Mixing Ratio Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:  RetrievedCOSurfaceMixingRatioMeanUncertaintyDay  RetrievedCOSurfaceMixingRatioMeanUncertaintyDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name: Retrieved CO Surface Mixing Ratio Mean Uncertainty Day Retrieved CO Surface Mixing Ratio Mean Uncertainty Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:  RetrievedCOSurfaceMixingRatioMeanUncertaintyNig  RetrievedCOSurfaceMixingRatioMeanUncertaintyNig
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name: Retrieved CO Surface Mixing Ratio Mean Uncertainty Night Retrieved CO Surface Mixing Ratio Mean Uncertainty Night
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:               RetrievedCOSurfaceMixingRatioNight               RetrievedCOSurfaceMixingRatioNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:          Retrieved CO Surface Mixing Ratio Night          Retrieved CO Surface Mixing Ratio Night
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:      RetrievedCOSurfaceMixingRatioVariabilityDay      RetrievedCOSurfaceMixingRatioVariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name: Retrieved CO Surface Mixing Ratio Variability Day Retrieved CO Surface Mixing Ratio Variability Day
#                             units:                                             ppbv                                             ppbv
#                -----VARIABLE-----:    RetrievedCOSurfaceMixingRatioVariabilityNight    RetrievedCOSurfaceMixingRatioVariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
# ...
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                     Satellite Zenith Angle Night                     Satellite Zenith Angle Night
#                             units:                                              deg                                              deg
#                -----VARIABLE-----:                                    SignalChi2Day                                    SignalChi2Day
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                                  Signal Chi2 Day                                  Signal Chi2 Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                                  SignalChi2Night                                  SignalChi2Night
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                                Signal Chi2 Night                                Signal Chi2 Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                         SignalChi2VariabilityDay                         SignalChi2VariabilityDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                      Signal Chi2 Variability Day                      Signal Chi2 Variability Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                       SignalChi2VariabilityNight                       SignalChi2VariabilityNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                    Signal Chi2 Variability Night                    Signal Chi2 Variability Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                SmoothingErrorCovarianceMatrixDay                SmoothingErrorCovarianceMatrixDay
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:            Smoothing Error Covariance Matrix Day            Smoothing Error Covariance Matrix Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:              SmoothingErrorCovarianceMatrixNight              SmoothingErrorCovarianceMatrixNight
#                             dtype:                                          float32                                          float32
#                             shape:                               (360, 180, 10, 10)                               (360, 180, 10, 10)
#                         chunksize:                                 [60, 30, 10, 10]                                 [60, 30, 10, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:          Smoothing Error Covariance Matrix Night          Smoothing Error Covariance Matrix Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                              SolarZenithAngleDay                              SolarZenithAngleDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                           Solar Zenith Angle Day                           Solar Zenith Angle Day
#                             units:                                              deg                                              deg
#                -----VARIABLE-----:                            SolarZenithAngleNight                            SolarZenithAngleNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                         Solar Zenith Angle Night                         Solar Zenith Angle Night
#                             units:                                              deg                                              deg
#                -----VARIABLE-----:                                  SurfaceIndexDay                                  SurfaceIndexDay
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                            -9999                                            -9999
#                         long_name:                                Surface Index Day                                Surface Index Day
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                                SurfaceIndexNight                                SurfaceIndexNight
#                             dtype:                                            int32                                            int32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                            -9999                                            -9999
#                         long_name:                              Surface Index Night                              Surface Index Night
#                             units:                                               NA                                               NA
#                -----VARIABLE-----:                               SurfacePressureDay                               SurfacePressureDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                             Surface Pressure Day                             Surface Pressure Day
#                             units:                                              hPa                                              hPa
#                -----VARIABLE-----:                             SurfacePressureNight                             SurfacePressureNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                           Surface Pressure Night                           Surface Pressure Night
#                             units:                                              hPa                                              hPa
#                -----VARIABLE-----:                    TotalColumnAveragingKernelDay                    TotalColumnAveragingKernelDay
#                             dtype:                                          float32                                          float32
#                             shape:                                   (360, 180, 10)                                   (360, 180, 10)
#                         chunksize:                                     [60, 30, 10]                                     [60, 30, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                Total Column Averaging Kernel Day                Total Column Averaging Kernel Day
#                             units:                              mol/(cm^2 log(VMR))                              mol/(cm^2 log(VMR))
#                -----VARIABLE-----:                  TotalColumnAveragingKernelNight                  TotalColumnAveragingKernelNight
#                             dtype:                                          float32                                          float32
#                             shape:                                   (360, 180, 10)                                   (360, 180, 10)
#                         chunksize:                                     [60, 30, 10]                                     [60, 30, 10]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:              Total Column Averaging Kernel Night              Total Column Averaging Kernel Night
#                             units:                              mol/(cm^2 log(VMR))                              mol/(cm^2 log(VMR))
#                -----VARIABLE-----:                              WaterVaporColumnDay                              WaterVaporColumnDay
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                           Water Vapor Column Day                           Water Vapor Column Day
#                             units:                                         mol/cm^2                                         mol/cm^2
#                -----VARIABLE-----:                            WaterVaporColumnNight                            WaterVaporColumnNight
#                             dtype:                                          float32                                          float32
#                             shape:                                       (360, 180)                                       (360, 180)
#                         chunksize:                                         [60, 30]                                         [60, 30]
#                        _FillValue:                                          -9999.0                                          -9999.0
#                         long_name:                         Water Vapor Column Night                         Water Vapor Column Night
#                             units:                                         mol/cm^2                                         mol/cm^2
#                                  - ------------------------------------------------ ------------------------------------------------
#      Total number of shared items:                                               88                                               88
#  Total number of non-shared items:                                                0                                                0
#
# Done.

# %% [markdown]
# END of Notebook.
