# %% [markdown]
# ### How to Access DSCOVR_EPIC_L2_TO3 Data using OPeNDAP with Python3 and Calculate Daily Statistics from Instantaneous Data
#
# * This instruction is based on Python3 and demonstrates how to remotely access the Deep Space Climate Observatory (DSCOVR, [1]) Earth Polychromatic Imaging Camera (EPIC, [2]) L2 instantaneous total ozone column data [3] files via OPeNDAP and analyze data such as resample instantaneous data into daily averages.
#
# 1. https://www.nesdis.noaa.gov/current-satellite-missions/currently-flying/dscovr-deep-space-climate-observatory
# 2. https://epic.gsfc.nasa.gov/about/epic
# 3. https://epic.gsfc.nasa.gov/science/products/o3
# * Last update: Dec. 28, 2023

# %% [markdown]
# This Python3 example code demonstrates how to remotely access a dataset archived in GES DISC using the Open-source Project for a Network Data Access Protocol (OPeNDAP) web service. We use DSCOVR_EPIC_L2_TO3_03 total ozone column product in this example. This collection is instantaneous total O3 column retrieval over entire Earth disk, 2048 lines by 2048 pixels, in each file (~165 MB per file, normally 16 - 18 files per day).

# %% [markdown]
# **Prerequisites**
#
# - This example code is written in Python3 (v3.9.2) Jupyter Notebook and requires these libraries: earthaccess, cartopy.crs (0.18.0), calendar, time, platform (make sure all packages are up to date). In particular, here is the instruction on how to install [cartopy](https://scitools.org.uk/cartopy/docs/v0.15/installing.html) and [earthaccess](https://earthaccess.readthedocs.io/en/latest/).
# - You can execute this example code in your Jupyter Notebook. This code has been tested with Jupyter Notebook v6.2.0 and v6.3.0 in Mac OS, Jupyter Notebook v6.1.4 in Windows OS. Or you can just run it in your Python 3 enviroment. This code has been tested in Python 3 in Mac, window and Linux OS.

# %% [markdown]
# **Caveats**:
#
# - Reading multiple hourly data files is a resource demanding task due to large data volume. It may take about 5 minutes to open one-month of the sample data (or longer if the data archive system is  currently heavily loaded). Be patient!
# - Visualizing the figures may also take time (~4 minute)
# - You may want to test first if your xarray package can read the data in your local disk before reading the data remotely as demonstrated in this case.

# %% [markdown]
# **Procedure**:
# 1. Register Earthdata account and set up the credential environment
#
# 2. Execute the Python code below in your Jupyter Notebook step-by-step
# - 2.1 Import the required Python modules or libraries. If any of the following import commands fail, check the local Python environment and install any missing packages.
#
# You can run this tutorial in your browser using Colab:<br>
#
# <a target="_blank" href="https://colab.research.google.com/github/OPENDAP/NASA-tutorials/blob/main/tutorials/daac-tutorials/How_to_Access_MERRA2_Using_OPeNDAP_with_Python3_Calculate_Weekly_from_Hourly.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 1. Install necessary libraries

# %% [markdown]
# - 1.1 netCDF4

# %%
! pip3 install netCDF4
# Out:
# Collecting netCDF4
#   Downloading netCDF4-1.6.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 11.0 MB/s eta 0:00:00
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4) (2023.11.17)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from netCDF4) (1.23.5)
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.3 netCDF4-1.6.5

# %% [markdown]
# - 1.2 shapely, cartopy, and earthaccess

# %%
! pip3 install shapely==1.7.1 cartopy earthaccess
# Out:
# Collecting shapely==1.7.1
#   Downloading Shapely-1.7.1.tar.gz (383 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.2/383.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cartopy
#   Downloading Cartopy-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 19.4 MB/s eta 0:00:00
# Collecting earthaccess
#   Downloading earthaccess-0.8.2-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.23.5)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.1)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.6.1)
# Requirement already satisfied: fsspec>=2022.11 in /usr/local/lib/python3.10/dist-packages (from earthaccess) (2023.6.0)
# Collecting multimethod>=1.8 (from earthaccess)
#   Downloading multimethod-1.10-py3-none-any.whl (9.9 kB)
# Collecting pqdm>=0.1 (from earthaccess)
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Collecting python-cmr>=0.9.0 (from earthaccess)
#   Downloading python_cmr-0.9.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from earthaccess) (2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.26 in /usr/local/lib/python3.10/dist-packages (from earthaccess) (2.31.0)
# Collecting s3fs<2024,>=2022.11 (from earthaccess)
#   Downloading s3fs-2023.12.2-py3-none-any.whl (28 kB)
# Collecting tinynetrc<2.0.0,>=1.3.1 (from earthaccess)
#   Downloading tinynetrc-1.3.1-py2.py3-none-any.whl (3.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (3.1.1)
# Collecting bounded-pool-executor (from pqdm>=0.1->earthaccess)
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pqdm>=0.1->earthaccess) (4.66.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pqdm>=0.1->earthaccess) (4.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.1.0->cartopy) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->earthaccess) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.26->earthaccess) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.26->earthaccess) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.26->earthaccess) (2.0.7)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs<2024,>=2022.11->earthaccess)
#   Downloading aiobotocore-2.9.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 4.7 MB/s eta 0:00:00
# Collecting fsspec>=2022.11 (from earthaccess)
#   Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from s3fs<2024,>=2022.11->earthaccess) (3.9.1)
# Collecting botocore<1.33.14,>=1.33.2 (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->earthaccess)
#   Downloading botocore-1.33.13-py3-none-any.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 42.7 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.10/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->earthaccess) (1.14.1)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->earthaccess)
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->earthaccess) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->earthaccess) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->earthaccess) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->earthaccess) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->earthaccess) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024,>=2022.11->earthaccess) (4.0.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.33.14,>=1.33.2->aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->earthaccess)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: shapely
#   Building wheel for shapely (setup.py) ... done
#   Created wheel for shapely: filename=Shapely-1.7.1-cp310-cp310-linux_x86_64.whl size=997425 sha256=b2fe0ceaf2742834a69b3682d74af143aaf9b6e030fc03b9b5bde3190fde3964
#   Stored in directory: /root/.cache/pip/wheels/2e/fa/97/c85f587c35afcaf4a81c481741d36592518d1e50445572f0d4
# Successfully built shapely
# Installing collected packages: tinynetrc, shapely, bounded-pool-executor, pqdm, multimethod, jmespath, fsspec, aioitertools, python-cmr, botocore, cartopy, aiobotocore, s3fs, earthaccess
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.2
#     Uninstalling shapely-2.0.2:
#       Successfully uninstalled shapely-2.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2023.12.2 which is incompatible.
# Successfully installed aiobotocore-2.9.0 aioitertools-0.11.0 botocore-1.33.13 bounded-pool-executor-0.0.3 cartopy-0.22.0 earthaccess-0.8.2 fsspec-2023.12.2 jmespath-1.0.1 multimethod-1.10 pqdm-0.2.0 python-cmr-0.9.0 s3fs-2023.12.2 shapely-1.7.1 tinynetrc-1.3.1

# %% [markdown]
# - 1.3 Import Authentication Libraries

# %%
import earthaccess
import os
import platform
from subprocess import Popen
import shutil

# %% [markdown]
# - 1.4 Create EDL files using the `earthaccess`
#
# First, pass your Earthdata credentials to the `earthaccess` library to create the `.netrc` file:

# %%
auth = earthaccess.login(strategy="interactive", persist=True)
# Out:
# Enter your Earthdata Login username: alexrad71
# Enter your Earthdata password: ··········
# Persisting credentials to .netrc

# %% [markdown]
# - 1.5 Run the following code to generate the `.dodsrc` file, if it is not already present

# %%
homeDir = os.path.expanduser("~") + os.sep

with open(homeDir + '.dodsrc', 'w') as file:
    file.write('HTTP.COOKIEJAR={}.urs_cookies\n'.format(homeDir))
    file.write('HTTP.NETRC={}.netrc'.format(homeDir))
    file.close()

print('Saved .dodsrc to:', homeDir)

# Set appropriate permissions for Linux/macOS
if platform.system() != "Windows":
    Popen('chmod og-rw ~/.netrc', shell=True)
else:
    # Copy dodsrc to working directory in Windows
    shutil.copy2(homeDir + '.dodsrc', os.getcwd())
    print('Copied .dodsrc to:', os.getcwd())
# Out:
# Saved .dodsrc to: /root/

# %% [markdown]
# # **PAUSE HERE!**
#
# ### Restart your runtime by selecting "Runtime" -> "Restart Runtime"

# %% [markdown]
# - 1.6 Then, import the rest of the packages:

# %%
# ----------------------
# Import Python modules
# ----------------------
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import netCDF4 as nc
import cartopy.crs as ccrs
import cartopy.feature as cfeature

#from calendar import monthrange
import time
import platform
print("platform.python_version() ", platform.python_version())
import requests
# Out:
# platform.python_version()  3.10.12

# %% [markdown]
# ### 2. Accessing, exploring, and gridding data

# %% [markdown]
# - 2.1 Remotely access the instantaneous DSCOVR_EPIC_L2_TO3 files through OPeNDAP [URL](https://opendap.larc.nasa.gov/opendap/).
#
# The user needs to choose year, month and range of days within the month, then the lists of available files are created for every day of interest.
#
# Please note that the version of the collection may change. Current version is 3, see product_version  = '03'. In order to check for the current version, please search [EarthData](https://search.earthdata.nasa.gov/search?q=DSCOVR_EPIC_L2_TO3).
#
# The line of "%%time" at the beginning of each cell is used for estimating the running time for that cell.

# %%
# %%time

sat_name = 'DSCOVR'
sensor_name = 'EPIC'
level = 'L2'
product = 'TO3'
product_version  = '03'

year = int(input('Enter year of interest, within the range 2015 - 2023: '))
month = int(input('Enter month of interest, in the range 1 - 12: '))
firstday = int(input('Enter the 1st day of interest: '))
lastday = int(input('Enter the last day of interest: '))

if lastday < firstday: sys.exit()

nd = lastday - firstday + 1
days = np.array(range(firstday, lastday + 1), dtype = int)
daily_granule_list = np.empty(nd, dtype = object)
for i in range(nd):
  daily_granule_list[i] = np.empty(0, dtype = str)

# OPeNDAP URL
url = 'https://opendap.larc.nasa.gov/opendap/{}/{}/{}_{}_{}/{:0>4d}/{:0>2d}/'.format(sat_name, sensor_name, level, product, product_version, year, month)
response = requests.get(url)
page = response.text

strings = page.split('\n')

granule_list = []
for s in strings:
# searching for file links
  qq = s.find('"sameAs": "')
  if qq < 0: continue
  qh5 = s.find('.h5')
  if qh5 >= 0:
    qp = s.rfind('"')
    fname = s[qq + 11 : qp]
# now check whether day is in the range on interest
    day = int(s[qh5 - 11 : qh5 - 9])
    if day < firstday or day > lastday: continue
    granule_list.append(s[qq + 11 : qh5 + 3])

    for i in range(nd):
      if day == days[i]:
        daily_granule_list[i] = np.append(daily_granule_list[i], s[qq + 11 : qh5 + 3])
        break

for i in range(nd):
  print('day', i+1,':', year, month, days[i], ', ', len(daily_granule_list[i]), ' granules:')
  for granule in daily_granule_list[i]:
    print(granule)
# Out:
# Enter year of interest, within the range 2015 - 2023: 2023
# Enter month of interest, in the range 1 - 12: 6
# Enter the 1st day of interest: 1
# Enter the last day of interest: 12
# day 1 : 2023 6 1 ,  16  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601000831_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601011358_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601064113_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601074640_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601085208_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601095735_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601110302_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601120830_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601131357_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601141924_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601152451_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601163019_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601194640_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601205208_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601215735_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601230303_03.h5
# day 2 : 2023 6 2 ,  16  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602002713_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602013240_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602023807_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602065956_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602080523_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602091050_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602101617_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602112144_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602122712_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602133239_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602143807_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602154334_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602200524_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602211052_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602221619_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230602232146_03.h5
# day 3 : 2023 6 3 ,  9  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603004554_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603015122_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603025649_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603061311_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603071839_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603202406_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603212934_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603223501_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230603234028_03.h5
# day 4 : 2023 6 4 ,  17  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604010437_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604021004_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604031531_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604063153_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604073720_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604084247_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604094814_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604105342_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604115909_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604130436_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604141004_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604151531_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604162058_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604193720_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604204247_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604214815_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230604225342_03.h5
# day 5 : 2023 6 5 ,  17  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605005516_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605020043_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605030610_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605062232_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605083326_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605093854_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605104421_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605114949_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605125516_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605140043_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605150610_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605161137_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605192800_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605203327_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605213855_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605224421_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230605234949_03.h5
# day 6 : 2023 6 6 ,  17  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606003634_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606014201_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606024728_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606060349_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606070916_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606081444_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606092011_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606102538_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606113105_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606123632_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606134200_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606144727_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606155254_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606201443_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606212011_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606222537_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230606233105_03.h5
# day 7 : 2023 6 7 ,  17  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607001751_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607012319_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607022846_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607065035_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607075602_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607090130_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607100657_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607111224_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607121751_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607132318_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607142846_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607153413_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607163940_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607195602_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607210130_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607220656_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230607231223_03.h5
# day 8 : 2023 6 8 ,  17  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608000830_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608011358_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608021925_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608064114_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608074641_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608085208_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608095735_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608110302_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608120830_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608131357_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608141925_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608152452_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608163020_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608194642_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608205210_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608215736_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230608230304_03.h5
# day 9 : 2023 6 9 ,  17  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609002713_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609013240_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609023807_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609055429_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609065956_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609080523_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609091050_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609101618_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609112145_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609122713_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609133240_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609143807_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609154334_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609200524_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609211052_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609221619_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230609232146_03.h5
# day 10 : 2023 6 10 ,  18  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610004554_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610015122_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610025649_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610061311_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610071838_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610082405_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610092933_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610103500_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610114028_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610124555_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610135123_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610145650_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610160217_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610191840_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610202408_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610212936_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610223502_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230610234030_03.h5
# day 11 : 2023 6 11 ,  17  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611010436_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611021004_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611031531_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611063154_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611073721_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611084248_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611094816_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611105343_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611115911_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611130438_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611141005_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611151533_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611162100_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611193722_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611204249_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611214818_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230611225344_03.h5
# day 12 : 2023 6 12 ,  18  granules:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612005515_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612020043_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612030611_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612062232_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612072759_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612083326_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612093854_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612104422_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612114949_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612125516_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612140044_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612150611_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612161139_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612192801_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612203328_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612213856_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612224423_03.h5
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230612234950_03.h5
# CPU times: user 851 ms, sys: 99.1 ms, total: 950 ms
# Wall time: 42.9 s

# %% [markdown]
# - 2.2 Exploring DSCOVR_EPIC_L2_TO3_03 datasets and their dimensions.

# %%
ncf = nc.Dataset(granule_list[0], diskless=True, persist=False)

print('file ' + granule_list[0] + ' has been opened')
#print(ncf)
print(ncf.variables.keys())
print(ncf.dimensions.keys())
for d in ncf.dimensions.items():
  print(d)
for var in ncf.variables.items():
  print(var)

ncf.close()
# Out:
# file https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601000831_03.h5 has been opened
# dict_keys(['AlgorithmFlag', 'CalibrationCoef', 'CloudPressure', 'ColumnWeightFunctionPercent', 'ControlFileContents', 'DNDomega', 'DNDreflectivity', 'ErrorFlag', 'ErythemalUV', 'LERTerrPres', 'NValue', 'NoABandCloud', 'NvalueAdjust', 'Ozone', 'OzoneStep1', 'RadiativeCloudFraction', 'RamanCorrection', 'Reflectivity', 'Residual', 'SatelliteAzimuthAngle', 'SatelliteZenithAngle', 'SlopeOfReflectivity', 'SolarAzimuthAngle', 'SolarZenithAngle', 'TerrainPressure', 'Wavelength', 'YearDaySeconds', 'Latitude', 'Longitude', 'FakeDim1', 'FakeDim3', 'FakeDim4', 'FakeDim5', 'FakeDim6', 'FakeDim7'])
# dict_keys(['FakeDim0', 'FakeDim1', 'FakeDim2', 'FakeDim3', 'FakeDim4', 'FakeDim5', 'FakeDim6', 'FakeDim7', 'maxStrlen64'])
# ('FakeDim0', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim0', size = 2048)
# ('FakeDim1', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim1', size = 3)
# ('FakeDim2', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim2', size = 2048)
# ('FakeDim3', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim3', size = 1)
# ('FakeDim4', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim4', size = 4)
# ('FakeDim5', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim5', size = 8)
# ('FakeDim6', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim6', size = 11)
# ('FakeDim7', <class 'netCDF4._netCDF4.Dimension'>: name = 'FakeDim7', size = 26)
# ('maxStrlen64', <class 'netCDF4._netCDF4.Dimension'>: name = 'maxStrlen64', size = 64)
# ('AlgorithmFlag', <class 'netCDF4._netCDF4.Variable'>
# int16 AlgorithmFlag(FakeDim0, FakeDim2)
#     origname: AlgorithmFlag
#     fullnamepath: /AlgorithmFlag
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('CalibrationCoef', <class 'netCDF4._netCDF4.Variable'>
# float32 CalibrationCoef(FakeDim4)
#     origname: CalibrationCoef
#     fullnamepath: /CalibrationCoef
# unlimited dimensions:
# current shape = (4,)
# filling off)
# ('CloudPressure', <class 'netCDF4._netCDF4.Variable'>
# float32 CloudPressure(FakeDim0, FakeDim2)
#     origname: CloudPressure
#     fullnamepath: /CloudPressure
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('ColumnWeightFunctionPercent', <class 'netCDF4._netCDF4.Variable'>
# int8 ColumnWeightFunctionPercent(FakeDim0, FakeDim2, FakeDim6)
#     origname: ColumnWeightFunctionPercent
#     fullnamepath: /ColumnWeightFunctionPercent
#     coordinates: Latitude Longitude FakeDim6
# unlimited dimensions:
# current shape = (2048, 2048, 11)
# filling off)
# ('ControlFileContents', <class 'netCDF4._netCDF4.Variable'>
# |S1 ControlFileContents(FakeDim7, maxStrlen64)
#     origname: ControlFileContents
#     fullnamepath: /ControlFileContents
# unlimited dimensions:
# current shape = (26, 64)
# filling off)
# ('DNDomega', <class 'netCDF4._netCDF4.Variable'>
# float32 DNDomega(FakeDim0, FakeDim2, FakeDim1)
#     origname: DNDomega
#     fullnamepath: /DNDomega
#     coordinates: Latitude Longitude FakeDim1
# unlimited dimensions:
# current shape = (2048, 2048, 3)
# filling off)
# ('DNDreflectivity', <class 'netCDF4._netCDF4.Variable'>
# float32 DNDreflectivity(FakeDim0, FakeDim2, FakeDim4)
#     origname: DNDreflectivity
#     fullnamepath: /DNDreflectivity
#     coordinates: Latitude Longitude FakeDim4
# unlimited dimensions:
# current shape = (2048, 2048, 4)
# filling off)
# ('ErrorFlag', <class 'netCDF4._netCDF4.Variable'>
# int16 ErrorFlag(FakeDim0, FakeDim2)
#     origname: ErrorFlag
#     fullnamepath: /ErrorFlag
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('ErythemalUV', <class 'netCDF4._netCDF4.Variable'>
# float32 ErythemalUV(FakeDim0, FakeDim2)
#     origname: ErythemalUV
#     fullnamepath: /ErythemalUV
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('LERTerrPres', <class 'netCDF4._netCDF4.Variable'>
# float32 LERTerrPres(FakeDim0, FakeDim2)
#     origname: LERTerrPres
#     fullnamepath: /LERTerrPres
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('NValue', <class 'netCDF4._netCDF4.Variable'>
# float32 NValue(FakeDim0, FakeDim2, FakeDim4)
#     origname: NValue
#     fullnamepath: /NValue
#     coordinates: Latitude Longitude FakeDim4
# unlimited dimensions:
# current shape = (2048, 2048, 4)
# filling off)
# ('NoABandCloud', <class 'netCDF4._netCDF4.Variable'>
# int32 NoABandCloud(FakeDim3)
#     origname: NoABandCloud
#     fullnamepath: /NoABandCloud
# unlimited dimensions:
# current shape = (1,)
# filling off)
# ('NvalueAdjust', <class 'netCDF4._netCDF4.Variable'>
# float32 NvalueAdjust(FakeDim4)
#     origname: NvalueAdjust
#     fullnamepath: /NvalueAdjust
# unlimited dimensions:
# current shape = (4,)
# filling off)
# ('Ozone', <class 'netCDF4._netCDF4.Variable'>
# float32 Ozone(FakeDim0, FakeDim2)
#     origname: Ozone
#     fullnamepath: /Ozone
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('OzoneStep1', <class 'netCDF4._netCDF4.Variable'>
# float32 OzoneStep1(FakeDim0, FakeDim2)
#     origname: OzoneStep1
#     fullnamepath: /OzoneStep1
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('RadiativeCloudFraction', <class 'netCDF4._netCDF4.Variable'>
# float32 RadiativeCloudFraction(FakeDim0, FakeDim2)
#     origname: RadiativeCloudFraction
#     fullnamepath: /RadiativeCloudFraction
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('RamanCorrection', <class 'netCDF4._netCDF4.Variable'>
# float32 RamanCorrection(FakeDim5, FakeDim4)
#     origname: RamanCorrection
#     fullnamepath: /RamanCorrection
# unlimited dimensions:
# current shape = (8, 4)
# filling off)
# ('Reflectivity', <class 'netCDF4._netCDF4.Variable'>
# float32 Reflectivity(FakeDim0, FakeDim2)
#     origname: Reflectivity
#     fullnamepath: /Reflectivity
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('Residual', <class 'netCDF4._netCDF4.Variable'>
# float32 Residual(FakeDim0, FakeDim2, FakeDim1)
#     origname: Residual
#     fullnamepath: /Residual
#     coordinates: Latitude Longitude FakeDim1
# unlimited dimensions:
# current shape = (2048, 2048, 3)
# filling off)
# ('SatelliteAzimuthAngle', <class 'netCDF4._netCDF4.Variable'>
# float32 SatelliteAzimuthAngle(FakeDim0, FakeDim2)
#     origname: SatelliteAzimuthAngle
#     fullnamepath: /SatelliteAzimuthAngle
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('SatelliteZenithAngle', <class 'netCDF4._netCDF4.Variable'>
# float32 SatelliteZenithAngle(FakeDim0, FakeDim2)
#     origname: SatelliteZenithAngle
#     fullnamepath: /SatelliteZenithAngle
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('SlopeOfReflectivity', <class 'netCDF4._netCDF4.Variable'>
# float32 SlopeOfReflectivity(FakeDim0, FakeDim2)
#     origname: SlopeOfReflectivity
#     fullnamepath: /SlopeOfReflectivity
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('SolarAzimuthAngle', <class 'netCDF4._netCDF4.Variable'>
# float32 SolarAzimuthAngle(FakeDim0, FakeDim2)
#     origname: SolarAzimuthAngle
#     fullnamepath: /SolarAzimuthAngle
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('SolarZenithAngle', <class 'netCDF4._netCDF4.Variable'>
# float32 SolarZenithAngle(FakeDim0, FakeDim2)
#     origname: SolarZenithAngle
#     fullnamepath: /SolarZenithAngle
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('TerrainPressure', <class 'netCDF4._netCDF4.Variable'>
# float32 TerrainPressure(FakeDim0, FakeDim2)
#     origname: TerrainPressure
#     fullnamepath: /TerrainPressure
#     coordinates: Latitude Longitude
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('Wavelength', <class 'netCDF4._netCDF4.Variable'>
# float32 Wavelength(FakeDim4)
#     origname: Wavelength
#     fullnamepath: /Wavelength
# unlimited dimensions:
# current shape = (4,)
# filling off)
# ('YearDaySeconds', <class 'netCDF4._netCDF4.Variable'>
# int32 YearDaySeconds(FakeDim1)
#     origname: YearDaySeconds
#     fullnamepath: /YearDaySeconds
# unlimited dimensions:
# current shape = (3,)
# filling off)
# ('Latitude', <class 'netCDF4._netCDF4.Variable'>
# float32 Latitude(FakeDim0, FakeDim2)
#     origname: Latitude
#     fullnamepath: /Latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('Longitude', <class 'netCDF4._netCDF4.Variable'>
# float32 Longitude(FakeDim0, FakeDim2)
#     origname: Longitude
#     fullnamepath: /Longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (2048, 2048)
# filling off)
# ('FakeDim1', <class 'netCDF4._netCDF4.Variable'>
# int32 FakeDim1(FakeDim1)
#     units: level
# unlimited dimensions:
# current shape = (3,)
# filling off)
# ('FakeDim3', <class 'netCDF4._netCDF4.Variable'>
# int32 FakeDim3(FakeDim3)
#     units: level
# unlimited dimensions:
# current shape = (1,)
# filling off)
# ('FakeDim4', <class 'netCDF4._netCDF4.Variable'>
# int32 FakeDim4(FakeDim4)
#     units: level
# unlimited dimensions:
# current shape = (4,)
# filling off)
# ('FakeDim5', <class 'netCDF4._netCDF4.Variable'>
# int32 FakeDim5(FakeDim5)
#     units: level
# unlimited dimensions:
# current shape = (8,)
# filling off)
# ('FakeDim6', <class 'netCDF4._netCDF4.Variable'>
# int32 FakeDim6(FakeDim6)
#     units: level
# unlimited dimensions:
# current shape = (11,)
# filling off)
# ('FakeDim7', <class 'netCDF4._netCDF4.Variable'>
# int32 FakeDim7(FakeDim7)
#     units: level
# unlimited dimensions:
# current shape = (26,)
# filling off)

# %% [markdown]
# - 2.3 Exploring ozone column and coordinates arrays
#
# Reading total ozone column along with latitude/longitude positions from the first available granule.
#
# Print the values in the center and in the corner to see actual fill values.
# As we have seen, fill value attributes are not set up. Due to the nature of the data, values in the corner, [0, 0], are fill values.

# %%
# ---------------------------------------------------
# Select variable of interest
# ---------------------------------------------------
o3_var_name = "Ozone"
lat_var_name = "Latitude"
lon_var_name = "Longitude"

# open the same granule file and read variables listed above
ncf = nc.Dataset(granule_list[0], diskless=True, persist=False)

o3 = np.array(ncf.variables[o3_var_name])
lat = np.array(ncf.variables[lat_var_name])
lon = np.array(ncf.variables[lon_var_name])

nx = ncf.dimensions['FakeDim0'].size
print(nx)
ny = ncf.dimensions['FakeDim2'].size
print(ny)

# close access to the granule file
ncf.close()

nx_c = nx//2
ny_c = ny//2
print('latitude of the center of the granule:', lat[nx_c, ny_c])
print('longitude of the center of the granule:', lon[nx_c, ny_c])
print('ozone column fill value:', o3[nx_c, ny_c])

fv_o3 = o3[0, 0]    # ozone fill value
fv_lat = lat[0, 0]  # latitude fill value
fv_lon = lon[0, 0]  # longitude fill value

print('ozone column fill value:', fv_o3)
print('latitude fill value:', fv_lat)
print('longitude fill value:', fv_lon)
mask = (o3 > 0.)&(lat != fv_lat)&(lon != fv_lon)
o3_loc = o3[mask].flatten()
print('number of valid pixels in the image', len(o3_loc))

# %% [markdown]
# - 2.4 Enter description of the output grid.
#
# User needs to select geographic box of interest along with the steps of the grid. The code asks for three parameters for both latitude and longitude:
#
# lat_l, lat_u, lat_delta: lower and upper latitudes and step;
#
# lon_l, lon_u, lon_delta: lower and upper longitudes and step.
#
# The centers of the gridboxes are computed as follow:
#
# nlat = int((lat_u - lat_l)/lat_delta),
#
# nlon = int((lon_u - lon_l)/lon_delta),
#
# lat = lat_l + lat_delta*(ilat + 0.5), ilat = 0, 1, ..., nlat - 1,
#
# lon = lon_l + lon_delta*(ilon + 0.5), ilon = 0, 1, ..., nlon - 1.
#
# Please be aware that the grid is step-driven, i.e. actual grid extent can be less than lat_u and lon_u while lat_u and lon_u are preserved.
# For example, if user chose lat_l = 10, lat_u = 15, lat_delta = 0.4
# nlat = int(5/.4) = 12 and the latitude of the center of the last gridbox is 10 + 0.4*(11 + .5) = 14.6 and its North extent is 14.8.
#
# The user is asked to confirm chosen grid.
#
# Example below is to show the impact of Canadian wildfires of 2023 to the US NorthEast. To do this, select the following spatial extent:
# Southmost latitude: 35
# Northmost latitude: 65
# latitude step: .25
# Westmost longitude: -90
# Easthmost longitude: -65
# longitude step: .2

# %%
confirmation = ''
while confirmation != 'Y':
  lat_l = float(input('Enter the Southmost latitude: '))
  lat_u = float(input('Enter the Northmost latitude: '))
  lat_delta = float(input('Enter the latitude step: '))

  lon_l = float(input('Enter the Westmost longitude: '))
  lon_u = float(input('Enter the Easthmost longitude: '))
  lon_delta = float(input('Enter the longitude step: '))

  nlat = int((lat_u - lat_l)/lat_delta)
  nlon = int((lon_u - lon_l)/lon_delta)

  lat_min = lat_l
  lat_max = lat_l + lat_delta*nlat
  lon_min = lon_l
  lon_max = lon_l + lon_delta*nlon

  print('latitude extent ', lat_min, lat_max, 'latitude step ', lat_delta)
  print('longitude extent ', lon_min, lon_max, 'longitude step ', lon_delta)
  confirmation = input('Please confirm your choice of the grid, Y for "yes", any character for "no": ')
# Out:
# Enter the Southmost latitude: 35
# Enter the Northmost latitude: 65
# Enter the latitude step: .25
# Enter the Westmost longitude: -90
# Enter the Easthmost longitude: -65
# Enter the longitude step: .2
# latitude extent  35.0 65.0 latitude step  0.25
# longitude extent  -90.0 -65.0 longitude step  0.2
# Please confirm your choice of the grid, Y for "yes", any character for "no": Y

# %% [markdown]
# - 2.5 Gridding data to the selected grid
#
# Though spatial sub-setting of L2 product cannot be done in OPENDAP, it can be done before gridding and averaging data. This is done by adding extra conditions on latitudes and longitudes besides removing fill values.

# %%
# create output array
avg_O3 = np.zeros([nd, nlat, nlon], dtype = float)
cnt_O3 = np.zeros([nd, nlat, nlon], dtype = int)
for i in range(nd):
  for granule in daily_granule_list[i]:
    ncf = nc.Dataset(granule, diskless=True, persist=False)

    o3 = np.array(ncf.variables[o3_var_name]).flatten()
    lat = np.array(ncf.variables[lat_var_name]).flatten()
    lon = np.array(ncf.variables[lon_var_name]).flatten()
    ncf.close()

    mask = (o3 > 0.)&(lat != fv_lat)&(lon != fv_lon)&(lat > lat_min)&(lat < lat_max)&(lon > lon_min)&(lon < lon_max)

    o3_m = o3[mask]
    lat_m = lat[mask]
    lon_m = lon[mask]
    nmask = len(o3_m)
    for imask in range(nmask):
      ilat = int((lat_m[imask] - lat_min)/lat_delta)
      ilon = int((lon_m[imask] - lon_min)/lon_delta)
      avg_O3[i, ilat, ilon] = avg_O3[i, ilat, ilon] + o3_m[imask]
      cnt_O3[i, ilat, ilon] = cnt_O3[i, ilat, ilon] + 1

    print(granule) # this print is added to control the progress, it can be painlessly removed

mask_all = (cnt_O3[i, ilat, ilon] > 0)
avg_O3[mask_all] = avg_O3[mask_all]/cnt_O3[mask_all]
# Out:
# https://opendap.larc.nasa.gov/opendap/hyrax/DSCOVR/EPIC/L2_TO3_03/2023/06/DSCOVR_EPIC_L2_TO3_03_20230601000831_03.h5

# %% [markdown]
#  - 3. Plotting maps of daily average O3 columns

# %%
# %%time
lon = lon_min + lon_delta*(np.arange(nlon)+.5)
lon_all = np.empty([nlat, nlon])
for ilat in range(nlat): lon_all[ilat, :] = lon[:]

lat = lat_min + lat_delta*(np.arange(nlat)+.5)
lat_all = np.empty([nlat, nlon])
for ilon in range(nlon): lat_all[:, ilon] = lat[:]

for i in range(nd):
  ax = plt.axes(projection=ccrs.PlateCarree())
  ax.coastlines(resolution='110m', color='black', linewidth=1)
  ax.add_feature(cfeature.LAKES.with_scale('110m'), facecolor='none', edgecolor='black')

  im = ax.scatter(lon_all, lat_all, c=avg_O3[i, :, :], s=1, cmap=plt.cm.jet, vmin=200., vmax=500.,
                  transform=ccrs.PlateCarree())
  cb = plt.colorbar(im, ticks=[200, 300, 400, 500, 600], fraction=0.022, pad=0.01)
  cb.set_label('DU', fontsize=10)
  ax.set_title('avg '+o3_var_name+str(' %4d %2.2d %2.2d' %(year, month, days[i])), size = 10)

  plt.savefig('avg_'+o3_var_name+str('_%4d_%2.2d_ %2.2d' %(year, month, days[i]))+'.png', dpi=600)
  plt.show()
  plt.close()
# Out:
# CPU times: user 4.61 s, sys: 365 ms, total: 4.97 s
# Wall time: 4.72 s
